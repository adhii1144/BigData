# %% [markdown]
# <a href="https://colab.research.google.com/github/adhii1144/BigData/blob/main/BigData1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd   #used to import the pamdas

# %%
data = pd.read_csv('crime.csv')   # reading the dataset using the pandas and storing in the data

# %%
data   # used to display the data
# Out:
#     Year  Population  Murder  Rape  Robbery  Assault  Burglary  CarTheft
# 0   1965    18073000     836  2320    28182    27464    183443     58452
# 1   1966    18258000     882  2439    30098    29142    196127     64368
# 2   1967    18336000     996  2665    40202    31261    219157     83775
# 3   1968    18113000    1185  2527    59857    34946    250918    104877
# 4   1969    18321000    1324  2902    64754    36890    248477    115400
# 5   1970    18190740    1444  2875    81149    39145    267474    125674
# 6   1971    18391000    1823  3225    97682    42318    273704    127658
# 7   1972    18366000    2026  4199    86391    45926    239886    105081
# 8   1973    18265000    2040  4852    80795    47781    246246    112328
# 9   1974    18111000    1919  5240    86814    51454    271824    104095
# 10  1975    18120000    1996  5099    93499    54593    301996    116274
# 11  1976    18084000    1969  4663    95718    54638    318919    133504
# ...

# %%
data.head()    #  tail is used to display the data of first 10 rows
# Out:
#    Year  Population  Murder  Rape  Robbery  Assault  Burglary  CarTheft
# 0  1965    18073000     836  2320    28182    27464    183443     58452
# 1  1966    18258000     882  2439    30098    29142    196127     64368
# 2  1967    18336000     996  2665    40202    31261    219157     83775
# 3  1968    18113000    1185  2527    59857    34946    250918    104877
# 4  1969    18321000    1324  2902    64754    36890    248477    115400

# %%
data.head(10)   # used to display the data of 10 rows
# Out:
#    Year  Population  Murder  Rape  Robbery  Assault  Burglary  CarTheft
# 0  1965    18073000     836  2320    28182    27464    183443     58452
# 1  1966    18258000     882  2439    30098    29142    196127     64368
# 2  1967    18336000     996  2665    40202    31261    219157     83775
# 3  1968    18113000    1185  2527    59857    34946    250918    104877
# 4  1969    18321000    1324  2902    64754    36890    248477    115400
# 5  1970    18190740    1444  2875    81149    39145    267474    125674
# 6  1971    18391000    1823  3225    97682    42318    273704    127658
# 7  1972    18366000    2026  4199    86391    45926    239886    105081
# 8  1973    18265000    2040  4852    80795    47781    246246    112328
# 9  1974    18111000    1919  5240    86814    51454    271824    104095

# %%
data.tail(10)   # tail is used to display the last 10 lines data
# Out:
#     Year  Population  Murder  Rape  Robbery  Assault  Burglary  CarTheft
# 37  2002    19134293     909  3885    36653    53583     76700     47366
# 38  2003    19212425     934  3775    35790    48987     75453     45204
# 39  2004    19280727     889  3608    33506    46911     70696     41002
# 40  2005    19315721     874  3636    35179    46150     68034     35736
# 41  2006    19306183     921  3169    34489    45387     68565     32134
# 42  2007    19297729     801  2926    31094    45094     64857     28030
# 43  2008    19467789     836  2799    31789    42122     65537     25096
# 44  2009    19541453     781  2582    28141    43606     62769     21871
# 45  2010    19395206     868  2797    28630    44197     65839     20639
# 46  2011    19465197     774  2752    28396    45568     65397     19311

# %%
type(data)    # used to find the data type of the data
# Out:
# pandas.core.frame.DataFrame

# %%
pd.core.frame.DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
data.isnull().tail()   # used to find the any null values in the last 5 rows
# Out:
#      Year  Population  Murder   Rape  Robbery  Assault  Burglary  CarTheft
# 42  False       False   False  False    False    False     False     False
# 43  False       False   False  False    False    False     False     False
# 44  False       False   False  False    False    False     False     False
# 45  False       False   False  False    False    False     False     False
# 46  False       False   False  False    False    False     False     False

# %%
data.notnull().tail()  # to make no null values present or exsist
# Out:
#     Year  Population  Murder  Rape  Robbery  Assault  Burglary  CarTheft
# 42  True        True    True  True     True     True      True      True
# 43  True        True    True  True     True     True      True      True
# 44  True        True    True  True     True     True      True      True
# 45  True        True    True  True     True     True      True      True
# 46  True        True    True  True     True     True      True      True

# %%
data.isnull().sum()   # used to display the number of null values in each column
# Out:
# Year          0
# Population    0
# Murder        0
# Rape          0
# Robbery       0
# Assault       0
# Burglary      0
# CarTheft      0
# dtype: int64

# %%
data[data.Robbery.isnull()]
# Out:
# Empty DataFrame
# Columns: [Year, Population, Murder, Rape, Robbery, Assault, Burglary, CarTheft]
# Index: []

# %%
data.shape   # used to display the no of rows and columns
# Out:
# (47, 8)

# %%
data['Robbery'].value_counts()  # used to find how many times a values is repeted in a particular column
# Out:
# Robbery
# 28182     1
# 40539     1
# 112342    1
# 108154    1
# 102122    1
# 86617     1
# 72492     1
# 61822     1
# 56094     1
# 49125     1
# 43821     1
# 36555     1
# 103983    1
# 36653     1
# 35790     1
# 33506     1
# 35179     1
# 34489     1
# 31094     1
# 31789     1
# 28141     1
# 28630     1
# 112380    1
# 97434     1
# 30098     1
# 95718     1
# 40202     1
# 59857     1
# 64754     1
# 81149     1
# 97682     1
# 86391     1
# 80795     1
# 86814     1
# 93499     1
# 84703     1
# 89721     1
# 83785     1
# 93471     1
# 112273    1
# 120344    1
# 107843    1
# 94783     1
# 89900     1
# 89706     1
# 91360     1
# 28396     1
# Name: count, dtype: int64

# %%
for col in data.columns:
  display(data[col].value_counts())
# Out:
# Year
# 1965    1
# 2000    1
# 1991    1
# 1992    1
# 1993    1
# 1994    1
# 1995    1
# 1996    1
# 1997    1
# 1998    1
# 1999    1
# 2001    1
# 1989    1
# 2002    1
# 2003    1
# 2004    1
# 2005    1
# 2006    1
# 2007    1
# 2008    1
# 2009    1
# 2010    1
# 1990    1
# 1988    1
# 1966    1
# 1976    1
# 1967    1
# 1968    1
# 1969    1
# 1970    1
# 1971    1
# 1972    1
# 1973    1
# 1974    1
# 1975    1
# 1977    1
# 1987    1
# 1978    1
# 1979    1
# 1980    1
# 1981    1
# 1982    1
# 1983    1
# 1984    1
# 1985    1
# 1986    1
# 2011    1
# Name: count, dtype: int64
# Population
# 18073000    1
# 18976457    1
# 18058000    1
# 18119000    1
# 18197000    1
# 18169000    1
# 18136000    1
# 18185000    1
# 18137000    1
# 18175000    1
# 18196601    1
# 19084350    1
# 17950000    1
# 19134293    1
# 19212425    1
# 19280727    1
# 19315721    1
# 19306183    1
# 19297729    1
# 19467789    1
# 19541453    1
# 19395206    1
# 17990455    1
# 17898000    1
# ...

# %%
rows = len(data)
rows
# Out:
# 47

# %%
col = len(data.columns)
col
# Out:
# 8

# %%
data.describe()
# Out:
#               Year    Population       Murder         Rape        Robbery  \
# count    47.000000  4.700000e+01    47.000000    47.000000      47.000000
# mean   1988.000000  1.834426e+07  1549.978723  4200.425532   70429.297872
# std      13.711309  6.024504e+05   590.454265  1096.569507   30204.823764
# min    1965.000000  1.750669e+07   774.000000  2320.000000   28141.000000
# 25%    1976.500000  1.793700e+07   922.500000  3197.000000   36604.000000
# 50%    1988.000000  1.816900e+07  1683.000000  4199.000000   81149.000000
# 75%    1999.500000  1.868373e+07  2016.000000  5241.000000   94141.000000
# max    2011.000000  1.954145e+07  2605.000000  5706.000000  120344.000000
#
#             Assault       Burglary       CarTheft
# count     47.000000      47.000000      47.000000
# mean   58022.234043  189119.829787   97573.553191
# std    17455.534367   90256.257143   46707.064488
# min    27464.000000   62769.000000   19311.000000
# ...

# %%
data.Population.describe()
# Out:
# count    4.700000e+01
# mean     1.834426e+07
# std      6.024504e+05
# min      1.750669e+07
# 25%      1.793700e+07
# 50%      1.816900e+07
# 75%      1.868373e+07
# max      1.954145e+07
# Name: Population, dtype: float64

# %%
data.skew()
# Out:
# Year          0.000000
# Population    0.795669
# Murder        0.059733
# Rape         -0.237130
# Robbery      -0.134085
# Assault       0.464637
# Burglary     -0.020278
# CarTheft     -0.129653
# dtype: float64

# %%
data.var()
# Out:
# Year          1.880000e+02
# Population    3.629465e+11
# Murder        3.486362e+05
# Rape          1.202465e+06
# Robbery       9.123314e+08
# Assault       3.046957e+08
# Burglary      8.146192e+09
# CarTheft      2.181550e+09
# dtype: float64

# %%
data.kurtosis()
# Out:
# Year         -1.200000
# Population   -0.692220
# Murder       -1.513564
# Rape         -1.471445
# Robbery      -1.527674
# Assault      -0.482013
# Burglary     -1.186281
# CarTheft     -0.951036
# dtype: float64

# %%
data.dtypes
# Out:
# Year          int64
# Population    int64
# Murder        int64
# Rape          int64
# Robbery       int64
# Assault       int64
# Burglary      int64
# CarTheft      int64
# dtype: object
